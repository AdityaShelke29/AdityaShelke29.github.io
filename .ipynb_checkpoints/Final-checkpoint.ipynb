# %% [markdown]
# # **London Household Energy Usage**
#
# #### **Fall 2024 Data Science Project**
#
# Collaborators: Joseph Cho, Aditya Shelke, Ishaan Ghosh, & Grace Cai

# %% [markdown]
# #### **Contributions**
#
# **Joseph Cho**
#
# I helped with data cleaning, helped with the Kruskal Wallis test on acorn groups, and contributed to the development and presentation of our PROPHET and LSTM models, specifically the implementation and feature engineering.
#
# **Aditya Shelke**
#
#  For the exploratory data analysis, I worked on the Friedman test for seasonality. In addition, I was part of the data cleaning process and the development of our LSTM (long - short term memory) model to predict energy usage for 30 days given the last 30 days of data.
#
# **Ishaan Ghosh**
#
# I helped with the data exploration and hypothesis testing, and the final report creation. I did the Wilcoxon Signed-Rank Test to analyze differences in energy consumption on weekends vs. weekdays, contributed to our introduction and conclusion, and added a couple visualizations.
#
# **Grace Cai**
#
#  I helped with dataset curation and preprocessing by explaining why we chose the London energy dataset and adding acorn group to the energy data for each household. I created the graph comparing average energy consumption for each acorn and analyzed specific information from each household such as number of members.

# %% [markdown]
# ## **Table Of Contents**
# 1. [Introduction](#intro)
# 2. [Data Curation](#data-curation)
# 3. [Exploratory Data Analysis](#eda)
# 4. [Primary Analysis](#prima)
# 5. [Insights and Conclusions](#conc)

# %% [markdown]
# <a name="intro"></a>
#
# ## **Introduction**
#
# Our project aims to use time series data of energy consumption for a certain household to predict future energy consumption. We examine the following data for our analysis:
# * Energy consumption
# * Acorn (category based on household demographics)
# * Temperature
# * Humidity
# * Wind speed
# * Weekend
# * Season
#
#
# We want to answer the following questions:
# * How does energy consumption differ between Acorn groups?
# * How does the temperature affect the energy consumption?
# * How do temporal factors affect energy consumption? Are there seasonal trends?
# * Over the years, how will energy consumption increase/decrease?
#
# Answering these questions is important to understand how energy consumption changes due to weather and season. We hypothesize that lower temperatures in the winter will lead to increased energy usage due to increased usage of heaters. In addition, being able to predict how energy consumption will change in the future can help energy companies take measures to handle an increase in energy consumption. Individual households can also use this information to understand their own energy usage habits so they can be more mindful of the environment.

# %% [markdown]
# <a name="data-curation"></a>
#
# ## **Data Curation**
#
# #### **Data Source**
#
# https://www.kaggle.com/datasets/jeanmidev/smart-meters-in-london/data
#
# #### **What dataset did we choose?**
#
# The dataset we utilized was gathered as part of the Low Carbon London Project, which was an energy data collection scheme that ran in London, UK between the years 2011 to 2014, inclusive. The project involved installing smart meters in 5,566 households of varying income levels. Between 2011-11-23 and 2014-02-28, energy consumption was recorded for each household at 30 minute increments. This data was also represented in a daily fashion, where for each day for each household, the mean and standard deviation energy consumption for a thirty minute block was recorded. In addition to this, for each day for each household, the total energy consumption throughout the entire day was also recorded.
#
# Each household is categorized into an Acorn group, which represents a specific type of household. Acorn groups are a method utilized in the United Kingdom to categorize households based on their general similarity. For example, Acorn group Acorn-O represents “Stable Seniors” which is a large subset of the population of seniors who are solid middle class. Acorn groups include Acorn-A through Acorn-U (with the exception of R, S, T) in this dataset. Acorn groups are classified into Acorn Categories based on their similar income and wealth levels. There are households of 6 Acorn Categories present in this data (all included in the image below except “Not Private Households”).
#
# As part of the Low Carbon London Project, each household involved in the study had to provide information regarding their household and residence. They had to provide information including the number of rooms, number of bedrooms, and number of members of the household, which are the columns of data we take most interest in.
#
# Finally, we also have daily temperature and weather data for London collected via the DarkSky API. This information is separate from the LCLP, but it is nonetheless useful to understanding the relationship between weather and energy usage.
#
# ![](https://wiki.roadsafetyanalysis.org/wiki/images/5/5a/List_segment_.png)
#
# #### **Why did we choose this dataset?**
#
# We chose this dataset because it includes daily energy consumption data from 5,000+ households over 4 years, giving us a total of 3.5 million rows of data to analyze. The dataset also includes weather data such as maximum temperature which can impact energy consumption. According to Britain's Department for Business Energy and Industrial Strategy, only 5% of households in England have air conditioning, so energy usage should increase during the winter from heater usage rather than during the summer. Additionally, the dataset has general information regarding each acorn category such as household size, number of people in each household, and house type. We expect that households that have more people or are larger in size will have higher energy consumption levels. Lastly, the dataset has a list of UK holidays that we can use to see if there is a change in energy consumption on holidays versus non-holidays. We plan on using this dataset to train a model that will predict the energy consumption of a specific household based on various factors such as weather, date (weekend versus weekday or holiday vs non-holiday), and household size.

# %% [markdown]
# #### **Imports**

# %%
# !pip install scikit_posthocs --quiet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from math import sqrt
from scipy import stats
from scipy.signal import periodogram
import scikit_posthocs as sp
from datetime import datetime
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# #### **Mounting Data From Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/CMSC320 Project/
# Out:
# /content/drive/.shortcut-targets-by-id/1g2WDnYtwYUjrEX205HTh8ABD7cyoW0Tf/CMSC320 Project

# %% [markdown]
# #### **Overview of Tables**

# %% [markdown]
# **daily_df:** The first table of data we have is daily_df. Each row of this table represents the energy usage statistics for a single household on a single day (24 - hour period of time). The column LCLid represents the unique identifier for each household. The column energy_median, energy_mean, and energy_std represent the median, mean, and standard deviation of energy consumption per 30 minute period in the day. Consider that the Low Carbon London project collects data at 30 minute intervals. Then, for 48 intervals in the day, there is a measure of energy consumption for a household. Then, energy_median, energy_mean, and energy_std represent the median, mean, and standard deviation of energy consumption from those 48 intervals.
#
# The column energy_max and energy_min represent the maximum and minimum energy consumption measurements, and energy_sum represents the total energy consumption of a household in a particular day.

# %%
daily_df = pd.read_csv("data/daily_dataset.csv")
daily_df
# Out:
#              LCLid         day  energy_median  energy_mean  energy_max  \
# 0        MAC000131  2011-12-15         0.4850     0.432045       0.868
# 1        MAC000131  2011-12-16         0.1415     0.296167       1.116
# 2        MAC000131  2011-12-17         0.1015     0.189812       0.685
# 3        MAC000131  2011-12-18         0.1140     0.218979       0.676
# 4        MAC000131  2011-12-19         0.1910     0.325979       0.788
# ...            ...         ...            ...          ...         ...
# 3510428  MAC004977  2014-02-24         0.0950     0.118458       0.580
# 3510429  MAC004977  2014-02-25         0.0675     0.084208       0.176
# 3510430  MAC004977  2014-02-26         0.1080     0.120500       0.282
# 3510431  MAC004977  2014-02-27         0.0720     0.114062       0.431
# 3510432  MAC004977  2014-02-28         0.0970     0.097000       0.097
#
#          energy_count  energy_std  energy_sum  energy_min
# ...

# %% [markdown]
# **households_df:** This dataset maps each household ID to an acorn between ACORN-A and ACORN-U inclusive. LCLid is the unique identifier for each household. The column stdorToU is the kind of tariff applied (ToU the dynamic tariff in function of the days or Std the classic fixed tariff). Acorn is the acorn group that categorizes the household. Acorns_grouped is a more generalized classification of the household, however, we use a different grouping system from the same organization that made the acorn system (shown in image above). File is the name of the file that the household's data is in.

# %%
households_df = pd.read_csv("data/informations_households.csv")
households_df = households_df[households_df['Acorn'] != "ACORN-"]
groupings = {}
for acorn in ['ACORN-A', 'ACORN-B', 'ACORN-C']:
  groupings[acorn] = "Luxury"
for acorn in ['ACORN-D', 'ACORN-E']:
  groupings[acorn] = "Established"
for acorn in ['ACORN-F', 'ACORN-G', 'ACORN-H', 'ACORN-I', 'ACORN-J']:
  groupings[acorn] = "Thriving"
for acorn in ['ACORN-K', 'ACORN-L', 'ACORN-M', 'ACORN-N', 'ACORN-O']:
  groupings[acorn] = "Steadfast"
for acorn in ['ACORN-P', 'ACORN-Q', 'ACORN-R']:
  groupings[acorn] = "Stretched"
for acorn in ['ACORN-S', 'ACORN-T', 'ACORN-U']:
  groupings[acorn] = "Low Income"
groupings['ACORN-'] = "No Category"

households_df['Acorn_category'] = households_df['Acorn'].map(lambda acorn: groupings[acorn])
households_df
# Out:
#           LCLid stdorToU    Acorn Acorn_grouped       file Acorn_category
# 2     MAC000002      Std  ACORN-A      Affluent    block_0         Luxury
# 3     MAC003613      Std  ACORN-A      Affluent    block_0         Luxury
# 4     MAC003597      Std  ACORN-A      Affluent    block_0         Luxury
# 5     MAC003579      Std  ACORN-A      Affluent    block_0         Luxury
# 6     MAC003566      Std  ACORN-A      Affluent    block_0         Luxury
# ...         ...      ...      ...           ...        ...            ...
# 5561  MAC002056      Std  ACORN-U       ACORN-U  block_111     Low Income
# 5562  MAC004587      Std  ACORN-U       ACORN-U  block_111     Low Income
# 5563  MAC004828      Std  ACORN-U       ACORN-U  block_111     Low Income
# 5564  MAC001704      ToU  ACORN-U       ACORN-U  block_111     Low Income
# 5565  MAC002774      ToU  ACORN-U       ACORN-U  block_111     Low Income
#
# [5564 rows x 6 columns]

# %% [markdown]
# **weather_df:** This table of data maps each date in the range of dates we are interested in (2011 to 2014) to the weather on that day. We look at specific columns such as temperatureLow, temperatureHigh, and both of these values to calculate the average temperature for each day.

# %%
weather_df = pd.read_csv("data/weather_daily_darksky.csv")
weather_df["date"] = pd.to_datetime(pd.to_datetime(weather_df["temperatureHighTime"]).dt.date)
weather_df["temperatureAverage"] = (weather_df["temperatureLow"] + weather_df["temperatureHigh"]) / 2
weather_df
# Out:
#      temperatureMax   temperatureMaxTime  windBearing                 icon  \
# 0             11.96  2011-11-11 23:00:00          123                  fog
# 1              8.59  2011-12-11 14:00:00          198    partly-cloudy-day
# 2             10.33  2011-12-27 02:00:00          225    partly-cloudy-day
# 3              8.07  2011-12-02 23:00:00          232                 wind
# 4              8.22  2011-12-24 23:00:00          252  partly-cloudy-night
# ..              ...                  ...          ...                  ...
# 877            9.03  2014-01-26 16:00:00          233    partly-cloudy-day
# 878           10.31  2014-02-27 14:00:00          224    partly-cloudy-day
# 879           18.97  2014-03-09 14:00:00          172  partly-cloudy-night
# 880            8.83  2014-02-12 16:00:00          210                 wind
# 881            9.90  2014-02-15 12:00:00          233                 wind
#
# ...

# %% [markdown]
# **acorn_df:** This table of data provides information for each ACORN group. We can understand the table as follows. Each row of the table is an attribute, and a numerical value is provided based on that attribute for each of the ACORN groups. A value of 150, for example, means that for the given attribute, the ACORN group with the value 150 has 1.5 times more people with that attribute than on average. For example, consider row 0. We see that ACORN-B has a value of 83. This means that ACORN-B has 0.83 times the average number of 0 - 4 year olds at the national scale.

# %%
acorn_df = pd.read_csv("data/acorn_details.csv", encoding='iso-8859-1')
acorn_df
# Out:
#     MAIN CATEGORIES                CATEGORIES                  REFERENCE  \
# 0        POPULATION                       Age                    Age 0-4
# 1        POPULATION                       Age                   Age 5-17
# 2        POPULATION                       Age                  Age 18-24
# 3        POPULATION                       Age                  Age 25-34
# 4        POPULATION                       Age                  Age 35-49
# ..              ...                       ...                        ...
# 821    LEISURE TIME  Holiday Destination/Type                       Asia
# 822    LEISURE TIME  Holiday Destination/Type  Activity / Outdoor Sports
# 823    LEISURE TIME  Holiday Destination/Type                     Cruise
# 824    LEISURE TIME  Holiday Destination/Type                    Package
# 825    LEISURE TIME  Holiday Destination/Type              Self-catering
#
#      ACORN-A  ACORN-B  ACORN-C  ACORN-D  ACORN-E  ACORN-F  ACORN-G  ACORN-H  \
# ...

# %%
# replacing acorn columns with acorn category columns
acorn_category_df = pd.DataFrame({'Category': acorn_df['CATEGORIES'], 'Reference': acorn_df['REFERENCE']})
acorn_category_df['Luxury'] = acorn_df['ACORN-A'] + acorn_df['ACORN-B'] + acorn_df['ACORN-C']
acorn_category_df['Established'] = acorn_df['ACORN-D'] + acorn_df['ACORN-E']
acorn_category_df['Thriving'] = acorn_df['ACORN-F'] + acorn_df['ACORN-G'] + acorn_df['ACORN-H'] + acorn_df['ACORN-I'] + acorn_df['ACORN-J']
acorn_category_df['Steadfast'] = acorn_df['ACORN-K'] + acorn_df['ACORN-L'] + acorn_df['ACORN-M'] + acorn_df['ACORN-N'] + acorn_df['ACORN-O']
acorn_category_df['Stretched'] = acorn_df['ACORN-P'] + acorn_df['ACORN-Q']
# acorn_category_df['No Category'] = acorn_df['ACORN-']
acorn_category_df
# Out:
#                      Category                  Reference  Luxury  Established  \
# 0                         Age                    Age 0-4   232.0        220.0
# 1                         Age                   Age 5-17   313.0        163.0
# 2                         Age                  Age 18-24   204.0        207.0
# 3                         Age                  Age 25-34   177.0        348.0
# 4                         Age                  Age 35-49   298.0        242.0
# ..                        ...                        ...     ...          ...
# 821  Holiday Destination/Type                       Asia   402.0        416.0
# 822  Holiday Destination/Type  Activity / Outdoor Sports   714.0        212.0
# 823  Holiday Destination/Type                     Cruise   839.0         88.0
# 824  Holiday Destination/Type                    Package   548.0         98.0
# 825  Holiday Destination/Type              Self-catering   670.0        110.0
#
# ...

# %% [markdown]
# #### **Data Cleaning**

# %% [markdown]
# **Checking data types as a sanity check**

# %%
daily_df.dtypes
# Out:
# LCLid             object
# day               object
# energy_median    float64
# energy_mean      float64
# energy_max       float64
# energy_count       int64
# energy_std       float64
# energy_sum       float64
# energy_min       float64
# dtype: object

# %% [markdown]
# **Create column "date" that converts the "day" column to datetime format**

# %%
daily_df.insert(1, "date", pd.to_datetime(daily_df.pop("day"), format="%Y-%m-%d"))
daily_df.head()
# Out:
#        LCLid       date  energy_median  energy_mean  energy_max  energy_count  \
# 0  MAC000131 2011-12-15         0.4850     0.432045       0.868            22
# 1  MAC000131 2011-12-16         0.1415     0.296167       1.116            48
# 2  MAC000131 2011-12-17         0.1015     0.189812       0.685            48
# 3  MAC000131 2011-12-18         0.1140     0.218979       0.676            48
# 4  MAC000131 2011-12-19         0.1910     0.325979       0.788            48
#
#    energy_std  energy_sum  energy_min
# 0    0.239146       9.505       0.072
# 1    0.281471      14.216       0.031
# 2    0.188405       9.111       0.064
# 3    0.202919      10.511       0.065
# 4    0.259205      15.647       0.066

# %% [markdown]
# **Double check that date is the correct data type**

# %%
daily_df.dtypes
# Out:
# LCLid                    object
# date             datetime64[ns]
# energy_median           float64
# energy_mean             float64
# energy_max              float64
# energy_count              int64
# energy_std              float64
# energy_sum              float64
# energy_min              float64
# dtype: object

# %% [markdown]
# **Check for missing data in each column**

# %%
missing_data = daily_df.isna().sum()
missing_data
# Out:
# LCLid                0
# date                 0
# energy_median       30
# energy_mean         30
# energy_max          30
# energy_count         0
# energy_std       11331
# energy_sum          30
# energy_min          30
# dtype: int64

# %% [markdown]
# **Check the percentage of missing data for the entire dataset**

# %%
missing_data["energy_std"] / len(daily_df)
# Out:
# 0.003227806940055543

# %% [markdown]
# **Drop the missing data since it is less than 1% of the entire dataset**

# %%
daily_df = daily_df.dropna()
daily_df.shape
# Out:
# (3499102, 9)

# %% [markdown]
# **Add acorn category to daily dataset**

# %%
id_acorn_dic = {} # dictionary mapping key to category

for index, row in households_df.iterrows():
    id_acorn_dic[row['LCLid']] = row['Acorn_category']

daily_df.loc[:,'Acorn_category'] = daily_df['LCLid'].apply(lambda x: id_acorn_dic.get(x, 'No Category'))
daily_df
# Out:
# <ipython-input-16-fb947a00da6e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df.loc[:,'Acorn_category'] = daily_df['LCLid'].apply(lambda x: id_acorn_dic.get(x, 'No Category'))
#              LCLid       date  energy_median  energy_mean  energy_max  \
# 0        MAC000131 2011-12-15         0.4850     0.432045       0.868
# 1        MAC000131 2011-12-16         0.1415     0.296167       1.116
# 2        MAC000131 2011-12-17         0.1015     0.189812       0.685
# 3        MAC000131 2011-12-18         0.1140     0.218979       0.676
# 4        MAC000131 2011-12-19         0.1910     0.325979       0.788
# ...            ...        ...            ...          ...         ...
# ...

# %% [markdown]
# <a name="eda"></a>
#
# ## **Exploratory Data Analysis**
#
# Before we run any tests based on the given data, we should get a better understanding of the ACORN categories. How do they differ, and what can we learn about them from acorn_category_df? Here, we look specifically at two components of ACORN categories that has a significant impact on household energy consumption. These components are household size among ACORN categories and house size among ACORN categories. This helps explain the differences in energy consumption between different ACORN categories.

# %% [markdown]
# **Plot distribution of category from acorn details**

# %%
def plot_category_distribution(full_df, category, title):
  new_df = full_df[full_df['Category'] == category]

  categories = ["Luxury", "Established", "Thriving", "Steadfast", "Stretched"]
  for category in categories:
    new_df.loc[:,category] = new_df[category] / new_df[category].sum()
  new_df.plot.bar(x='Reference')
  plt.title(title)
  plt.ylabel("Proportion of households")
  plt.xlabel(category)
  plt.show()

# %%
plot_category_distribution(acorn_category_df, "Household Size", "Distribution of household size among acorn categories")

# %%
plot_category_distribution(acorn_category_df, "House Size", "Distribution of house size among acorn categories")

# %% [markdown]
# #### **Hypothesis Test 1: Wilcoxon Signed-Rank Test for Difference in Energy Consumption by Household on Weekdays vs. Weekends**
#
# Here, we get the average energy consumption for each household across all weekdays, and all weekends. We can pair these values by household, so we run the nonparametric version of a paired T-test, a Wilcoxon Signed-Rank test, on this data. We run the nonparametric version as the data doesn't indicate an underlying normal distribution for the population.
# The violin plot below shows that in the sample data we have, the average energy consumption per household is slightly higher on the weekends than on the weekdays, with both distributions heavily skewed towards the right.
#
# We expect that the weekend will show a higher average energy consumption, as people are more likely to be at home on the weekends and using energy. So, we have the hypotheses:
#
# H0: the true mean energy consumption of a household is the same on the weekend and the weekdays.
#
# Ha: the true mean energy consumption of a household is greater on the weekend than the weekdays.

# %%
daily_df['weekend'] = daily_df['date'].apply(lambda x: x.dayofweek > 4)
household_energy_consumption_by_weekday = daily_df.groupby(["LCLid", "weekend"])["energy_sum"].mean().reset_index()
household_energy_consumption_by_weekday = household_energy_consumption_by_weekday.drop(11116) # this specific household has no data for the weekends
weekday = household_energy_consumption_by_weekday[household_energy_consumption_by_weekday["weekend"] == False]["energy_sum"]
weekend = household_energy_consumption_by_weekday[household_energy_consumption_by_weekday["weekend"] == True]["energy_sum"]
fig = sns.violinplot([weekday.to_list(), weekend.to_list()])
fig.set_xticklabels(["Weekday", "Weekend"])
fig.set_ylabel("Mean Energy Consumption (kWh)")
fig.set_title("Mean Energy Consumption per Household by Weekdays vs. Weekends")
plt.show()
# Out:
# <ipython-input-20-4c9df7cf1a78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df['weekend'] = daily_df['date'].apply(lambda x: x.dayofweek > 4)
# <ipython-input-20-4c9df7cf1a78>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(["Weekday", "Weekend"])

# %%
stats.wilcoxon(weekday, weekend, alternative="less")
# Out:
# WilcoxonResult(statistic=3858574.0, pvalue=1.4358815427202813e-229)

# %% [markdown]
# Running the test gives a p-value very close to 0, which is less than our significance level of 0.05, so we reject the null hypothesis. There is sufficient evidence that the true mean energy consumption of a household is greater on the weekend than the weekdays.

# %% [markdown]
# #### **Hypothesis Test 2: Friedman Test for the Difference in Median Energy Consumption Between Seasons**
#
# Another aspect of the data that we are interested in is checking whether or not there is a statistically significant difference in the median average daily energy consumption for a household between seasons. Understanding if the seasons affect energy consumption allow us to better predict energy consumption going into the future.
#
# H0: the true median daily energy consumption per household is the same for all seasons.
#
# Ha: the true median daily energy consumption per household differ for at least two of the seasons.

# %% [markdown]
# **Adding season to our dataframe**

# %%
# Here, we add, for each row of data, the season that the data was recorded in.
# This is done using the get_season() function which takes in a date and converts it to
# the string "winter", "fall", "spring", or "summer".

def get_season(doy):
  spring = range(80, 172)
  summer = range(172, 264)
  fall = range(264, 355)

  if doy in spring:
    season = 'spring'
  elif doy in summer:
    season = 'summer'
  elif doy in fall:
    season = 'fall'
  else:
    season = 'winter'
  return season

daily_df["season"] = daily_df["date"].apply(lambda x: get_season(x.timetuple().tm_yday))

daily_df.head(15)
# Out:
# <ipython-input-22-cd92f09f4707>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daily_df["season"] = daily_df["date"].apply(lambda x: get_season(x.timetuple().tm_yday))
#         LCLid       date  energy_median  energy_mean  energy_max  \
# 0   MAC000131 2011-12-15         0.4850     0.432045       0.868
# 1   MAC000131 2011-12-16         0.1415     0.296167       1.116
# 2   MAC000131 2011-12-17         0.1015     0.189812       0.685
# 3   MAC000131 2011-12-18         0.1140     0.218979       0.676
# 4   MAC000131 2011-12-19         0.1910     0.325979       0.788
# 5   MAC000131 2011-12-20         0.2180     0.357500       1.077
# 6   MAC000131 2011-12-21         0.1305     0.235083       0.705
# ...

# %% [markdown]
# **Dropping households without data for all seasons**

# %%
filtered_daily_df = daily_df.groupby('LCLid').filter(lambda x: x['season'].nunique() == 4)
filtered_daily_df
# Out:
#              LCLid       date  energy_median  energy_mean  energy_max  \
# 0        MAC000131 2011-12-15         0.4850     0.432045       0.868
# 1        MAC000131 2011-12-16         0.1415     0.296167       1.116
# 2        MAC000131 2011-12-17         0.1015     0.189812       0.685
# 3        MAC000131 2011-12-18         0.1140     0.218979       0.676
# 4        MAC000131 2011-12-19         0.1910     0.325979       0.788
# ...            ...        ...            ...          ...         ...
# 3510427  MAC004977 2014-02-23         0.1365     0.174646       0.754
# 3510428  MAC004977 2014-02-24         0.0950     0.118458       0.580
# 3510429  MAC004977 2014-02-25         0.0675     0.084208       0.176
# 3510430  MAC004977 2014-02-26         0.1080     0.120500       0.282
# 3510431  MAC004977 2014-02-27         0.0720     0.114062       0.431
#
#          energy_count  energy_std  energy_sum  energy_min Acorn_category  \
# ...

# %% [markdown]
# **Grouping the data for the hypothesis test**

# %%
household_energy_consumption_by_season = filtered_daily_df.groupby(["LCLid", "season"])["energy_sum"].mean().reset_index()

fall = household_energy_consumption_by_season[household_energy_consumption_by_season["season"] == "fall"]["energy_sum"]
spring = household_energy_consumption_by_season[household_energy_consumption_by_season["season"] == "spring"]["energy_sum"]
summer = household_energy_consumption_by_season[household_energy_consumption_by_season["season"] == "summer"]["energy_sum"]
winter = household_energy_consumption_by_season[household_energy_consumption_by_season["season"] == "winter"]["energy_sum"]

print(f"Fall: {fall.shape}")
print(f"Spring: {spring.shape}")
print(f"Summer: {summer.shape}")
print(f"Winter: {winter.shape}")
# Out:
# Fall: (5512,)
# Spring: (5512,)
# Summer: (5512,)
# Winter: (5512,)

# %% [markdown]
# **Run Friedman test**

# %%
stats.friedmanchisquare(fall, spring, summer, winter)
# Out:
# FriedmanchisquareResult(statistic=7742.841469168515, pvalue=0.0)

# %% [markdown]
# The p-value is 0.0, which is less than our chosen significance level of 0.05, so we reject the null hypothesis. At least two of the seasons have a statistically significant difference in true median average daily energy consumption.

# %% [markdown]
# **Post hoc tests**

# %%
p_values = sp.posthoc_dunn([fall, spring, summer, winter], p_adjust = 'holm')
p_values
# Out:
#               1             2              3              4
# 1  1.000000e+00  1.659800e-18   1.026756e-71   8.770543e-08
# 2  1.659800e-18  1.000000e+00   1.853663e-19   3.342623e-45
# 3  1.026756e-71  1.853663e-19   1.000000e+00  8.747190e-120
# 4  8.770543e-08  3.342623e-45  8.747190e-120   1.000000e+00

# %%
sign_table = sp.sign_table(p_values)
sign_table
# Out:
#      1    2    3    4
# 1    -  ***  ***  ***
# 2  ***    -  ***  ***
# 3  ***  ***    -  ***
# 4  ***  ***  ***    -

# %% [markdown]
# Here, we ran the post hoc test for our Friedman test (which is Dunn's Test). We see that the p - value between different seasons are completely different and very close to 0, which shows that for all pairs of seasons, there is no similarity in the true median average daily energy consumption. We can see from the following visualization why this might be the case.
#
# We know that in the UK, the daily average temperature varies with season. From the below visualization, we see that average total energy consumption for a household is strongly negatively correlated with temperature. Thus, this visualization provides a good understanding of why we reject the null hypothesis -- because seasons have different average temperatures, and temperature is strongly correlated with energy consumption.

# %%
daily_average_energy = pd.DataFrame(daily_df.groupby("date")["energy_sum"].mean()).reset_index()
daily_average_temperature = pd.DataFrame(weather_df.groupby("date")["temperatureAverage"].mean()).reset_index()

daily_average_temperature["date"] = pd.to_datetime(daily_average_temperature["date"])

print(daily_average_energy.head())
print(daily_average_temperature.head())
# Out:
#         date  energy_sum
# 0 2011-11-23    6.952692
# 1 2011-11-24    8.536480
# 2 2011-11-25    9.499781
# 3 2011-11-26   10.267707
# 4 2011-11-27   10.850805
#         date  temperatureAverage
# 0 2011-11-01              12.225
# 1 2011-11-02              14.525
# 2 2011-11-03              14.965
# 3 2011-11-04              12.855
# 4 2011-11-05              11.700

# %%
daily_energy_and_temperature = daily_average_energy.merge(daily_average_temperature, left_on = "date", right_on = "date")
daily_energy_and_temperature.head()
# Out:
#         date  energy_sum  temperatureAverage
# 0 2011-11-23    6.952692               9.300
# 1 2011-11-24    8.536480              11.320
# 2 2011-11-25    9.499781               9.640
# 3 2011-11-26   10.267707              12.275
# 4 2011-11-27   10.850805               7.425

# %%
import seaborn as sns

# Create the scatter plot with a regression line and set the line color
sns.lmplot(x="temperatureAverage", y="energy_sum", data=daily_energy_and_temperature, ci=None,
           line_kws={'color': 'red'})  # You can change 'red' to any color you prefer

# Add title and labels
plt.title("Average Daily Temperature vs. Average Household Energy Consumption")
plt.xlabel("Temperature (C)")
plt.ylabel("Kilowatt Hours (KWh)")

plt.show()

# %%
correlation_matrix = daily_energy_and_temperature[["energy_sum", "temperatureAverage"]].corr()
print(correlation_matrix)
# Out:
#                     energy_sum  temperatureAverage
# energy_sum            1.000000           -0.869429
# temperatureAverage   -0.869429            1.000000

# %% [markdown]
# Additionally, as a further indication of seasonality, we also performed some spectrum anaylsis on the daily energy consumption data. To do this, we created a periodogram for the data.
#
# However, as a caveat, since our data only spans about 2-3 years, the confidence of our results may not be the best. Either way, we thought that including this would be interesting.
#
# As context, a periodogram is a visualization that shows the spectral density of range of frequencies. If there is a peak at a certain frequency, we can take the reciprocal of it to see the size of the dominant cycle. If the dominant cycle is around a year, which in this case is 365, there is a good chance that the data can be viewed as having yearly cycles.

# %%
two_year_df = daily_df[
  (daily_df["date"] >= datetime(month=1, day=1, year=2012)) &
  (daily_df["date"] < datetime(month=1, day=1, year=2014))
]

f, Pxx = periodogram(two_year_df.groupby("date")["energy_sum"].mean())

plt.figure()
plt.plot(f, Pxx)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.title('Periodogram For Daily Energy Consumption')
plt.show()

# %% [markdown]
# Here, we see a peek in the periodogram, indicating a dominant frequency.

# %%
Pxx.tolist()[:10]
# Out:
# [4.8501456257528254e-29,
#  7.226547749176437,
#  2230.1090415913723,
#  3.075438333006837,
#  20.852283414426253,
#  17.846620448164796,
#  16.529932738248377,
#  15.250836869437132,
#  1.3835518736254544,
#  26.063783493986836]

# %%
f.tolist()[:10]
# Out:
# [0.0,
#  0.0013679890560875513,
#  0.0027359781121751026,
#  0.004103967168262654,
#  0.005471956224350205,
#  0.006839945280437756,
#  0.008207934336525308,
#  0.009575923392612859,
#  0.01094391244870041,
#  0.012311901504787962]

# %% [markdown]
# We see that the most dominant frequency is in the 3rd element of the list

# %%
1/f.tolist()[2]
# Out:
# 365.5

# %% [markdown]
# Now, after some calculations, we can see that the most dominant frequency indicates a periodicity of about a year, which reinforces that the data is likely seasonal.
#
# As another supplemental analysis, we also performed seasonal decomposition.

# %%
res = sm.tsa.seasonal_decompose(two_year_df.groupby("date")["energy_sum"].mean(), period=365)
res.plot()
plt.show()

# %% [markdown]
# Here, we see that the seasonal portion of the decomposition follows much of the trends of the original data, thus providing a positive indicator that the data is seasonal.

# %% [markdown]
# #### **Test 3: Kruskal-Wallis Test For Difference In Median Energy Consumption Between ACORNS**
#
# Another aspect of the data that we are interested in is checking whether or not there is a statistically significant difference in the median average daily energy consumption for a household between acorn groups. Understanding if the acorn group affects energy consumption will also allow us to better predict energy consumption going into the future.
#
# H0: the true median daily energy consumption per household is the same for all acorn groups.
#
# Ha: the true median daily energy consumption per household differ for at least two of the acorn groups.

# %% [markdown]
# **Gather necessary data for the test**

# %%
acorns = ["Low Income", "Stretched", "Steadfast", "Thriving", "Established", "Luxury"]
household_energy_consumption_by_acorn = daily_df.groupby(["LCLid", "Acorn_category"])["energy_sum"].mean().reset_index()

acorn_means = []

for acorn in acorns:
  sample = household_energy_consumption_by_acorn[household_energy_consumption_by_acorn["Acorn_category"] == acorn]["energy_sum"]
  acorn_means.append(sample)

for acorn, means in zip(acorns, acorn_means):
  print(f"{acorn}: {means.shape}")
# Out:
# Low Income: (49,)
# Stretched: (938,)
# Steadfast: (875,)
# Thriving: (1505,)
# Established: (1859,)
# Luxury: (333,)

# %% [markdown]
# **Visualize distribution of energy sum per household by Acorn group**

# %%
fig = sns.violinplot([s.to_list() for s in acorn_means])
fig.set_xticklabels(acorns)
fig.set_ylabel("Mean Energy Sum (kWh)")
fig.set_title("Mean Energy Sum per Household by Acorn Group")
plt.show()
# Out:
# <ipython-input-38-cedc26df46c7>:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels(acorns)

# %% [markdown]
# **Run the test**

# %%
stats.kruskal(*acorn_means)
# Out:
# KruskalResult(statistic=329.43697054085715, pvalue=4.667635463114512e-69)

# %% [markdown]
# The p-value is very close to 0, which is less than our chosen significance level of 0.05, so we reject the null hypothesis. At least two of the acorns groups have a statistically significant difference in true median average daily energy consumption.

# %% [markdown]
# **Post hoc tests**

# %%
p_values = sp.posthoc_dunn(acorn_means, p_adjust='holm')
p_values
# Out:
#           1             2             3             4             5  \
# 1  1.000000  4.735542e-03  1.000000e+00  1.000000e+00  1.000000e+00
# 2  0.004736  1.000000e+00  3.831102e-26  7.915818e-34  1.483883e-31
# 3  1.000000  3.831102e-26  1.000000e+00  1.000000e+00  1.000000e+00
# 4  1.000000  7.915818e-34  1.000000e+00  1.000000e+00  1.000000e+00
# 5  1.000000  1.483883e-31  1.000000e+00  1.000000e+00  1.000000e+00
# 6  0.001382  2.744578e-62  1.575579e-17  2.494202e-19  1.419967e-22
#
#               6
# 1  1.382068e-03
# 2  2.744578e-62
# 3  1.575579e-17
# 4  2.494202e-19
# 5  1.419967e-22
# 6  1.000000e+00

# %%
print("-----Key-----")
for i, acorn in enumerate(acorns):
  print(f"{i+1}: {acorn}")
# Out:
# -----Key-----
# 1: Low Income
# 2: Stretched
# 3: Steadfast
# 4: Thriving
# 5: Established
# 6: Luxury

# %%
sign_table = sp.sign_table(p_values)
sign_table
# Out:
#     1    2    3    4    5    6
# 1   -   **   NS   NS   NS   **
# 2  **    -  ***  ***  ***  ***
# 3  NS  ***    -   NS   NS  ***
# 4  NS  ***   NS    -   NS  ***
# 5  NS  ***   NS   NS    -  ***
# 6  **  ***  ***  ***  ***    -

# %% [markdown]
# Here, we ran the post hoc test for Kruskal Wallis (which is Dunn's Test). As context, in the sign table, a `*`, `**`, or `***` represents a statistically significant pairing while `NS` represents a pairing that is not statistically different.
#
# We can see in the sign table that there about half of the pairings are statistically significant while the other half are not. Overall, though, this does showcase that different Acorn groups have different median average daily energy consumptions. The below visualization provides more visual evidence for this finding, as well.

# %%
fig, ax = plt.subplots(figsize=(12, 8))

energy_sum = daily_df.groupby(['Acorn_category', 'date'])['energy_sum'].mean().reset_index()
energy_sum = energy_sum[energy_sum['Acorn_category'] != "No Category"]
energy_sum

for name, group in energy_sum.groupby('Acorn_category'):
    group.plot(x='date', y='energy_sum', ax=ax, label=name)

plt.ylabel('Mean total daily energy consumption (KWH)')
plt.title('Mean Total Daily Energy Consumption by Acorn Category')
plt.legend(title='Acorn Category')

plt.show()

# %% [markdown]
# This graph shows the mean daily total energy consumption for each acorn category between 2011 and 2014. On average, households in the Luxury category have the highest energy consumption while households in the Stretched category have the lowest energy consumption levels. While the energy consumption levels are sequentially lower from higher to lower income households, the Low Income category has the second highest energy consumption levels between August 2012 and April 2013 after the Luxury category. All of the lines also show an increasing in energy consumption during the winter months between December and February and a decrease in energy consumption during the summer months between June and September. This makes sense because most England households do not have AC so their energy usage would increase during the winter when they need heating.

# %% [markdown]
# #### **Supplemental Test: ADF Stationary Test For Acorn Groups**
#
# As some supplemental analysis, we also performed ADF tests for each acorn for daily energy consumption in order to inform us if the data is stationary or not for each acorn. This could serve as useful information when choosing our forecasting model in the future since stationary data is either mandatory or recommended for some models.
#
# The hypotheses for each acorn are below.
#
# H0: a unit root is present in the time series data for average daily consumption for the specified acorn type
#
# Ha: the time series data has no unit root, meaning that the data is stationary for the specified acorn type

# %%
def perform_tests(df):
  average_df = df.groupby("date")[["energy_sum"]].mean()
  pvalues = []
  series = average_df["energy_sum"]
  pvalue = np.NaN if np.all(series == series.iloc[0]) else adfuller(series)[1]
  pvalues.append(pvalue)
  return pvalues

acorn_dfs = daily_df.groupby("Acorn_category")[["energy_sum", "date"]]
adf_df = pd.DataFrame(columns=["energy_sum"])
for acorn, acorn_subset_df in acorn_dfs:
  pvalues = perform_tests(acorn_subset_df)
  adf_df.loc[acorn] = pvalues
adf_df
# Out:
#              energy_sum
# Established    0.229401
# Low Income     0.372457
# Luxury         0.233889
# No Category    0.326184
# Steadfast      0.084336
# Stretched      0.285624
# Thriving       0.261185

# %% [markdown]
# Here, we see that for each acorn, the p-value is greater than 0.05, indicating that we fail to reject the null hypothesis for each acorn group, meaning that the data for all acorn groups is not stationary.

# %% [markdown]
# <a name="prima"></a>
#
# ### **ML & Primary Analysis**

# %% [markdown]
# To recap the above findings, we have determined that
#
# - Average daily energy usage is greater on weekends than weekdays
# - Average daily energy usage is different for each season, following a yearly seasonal trend due to cyclic factors such as temperature
# - Avarage daily energy usage is different amongst acorn groups
# - Average daily energy usage is not stationary for our dataset
#
# Given these findings, as well as the fact that we intend to forecast daily energy usage, which is a continuous variable, we can determine that we need to utilize a regression model that works well on non-stationary seasonal datasets.
#
# Since the dataset is not stationary, we can't necessarily utilize ARIMA or SARIMA, which are popular seasonal models, (at least optimally) with the dataset as is.
#
# Other models exist though that don't require this requirement.
#
# The two that we chose for our tutorial are
#
# 1. PROPHET
# 2. LSTM
#
# First, the PROPHET model is a statistical model that works very well for seasonal data, and unlike ARIMA or SARIMA, it does not require stationary data.
#
# To account for spikes for weekends that we observed above, we can also attach a boolean integer variable `is_weekend` to the model as a additional regressor.
#
# Second, LSTM is a type of RNN model that can be used for timeseries forecasting. The model is certainly more complicated than PROPHET and requires more feature engineering and hyperparameter tuning. However, due to the fluctuations that occur on top of the yearly seasonality, we thought that it is at least worth a try.
#
# As an important note before we continue to the models, since there is a difference in average energy usage between acorn groups as described above, we chose for the sake of the tutorial to train the models on an average of all of the daily energy usages for the acorn group `Established` (basically bucketing all of the data for this acorn to daily buckets then averaging those). The implementation will be done below whenever we prepare our model data.

# %% [markdown]
# #### **PROPHET Model**

# %% [markdown]
# **Imports**

# %%
from prophet import Prophet

# %% [markdown]
# **Preparing Data**
#
# As hinted at above, the PROPHET model will forecast `y = energy_sum` with an additional regressor in `is_weekend`.

# %%
sample_df = daily_df[daily_df["Acorn_category"] == "Established"]
sample_df = sample_df.drop(columns="LCLid")
sample_df = sample_df.groupby("date")["energy_sum"].mean().reset_index()
sample_df["is_weekend"] = pd.to_datetime(sample_df["date"]).apply(lambda x: int(x.dayofweek > 4))
prophet_df = sample_df[['date', 'energy_sum']].rename(columns={'date': 'ds', 'energy_sum': 'y'})
prophet_df['is_weekend'] = sample_df['is_weekend']
prophet_df
# Out:
#             ds          y  is_weekend
# 0   2011-11-23  11.551500           0
# 1   2011-11-24  10.654900           0
# 2   2011-11-25  11.062214           0
# 3   2011-11-26  12.207176           1
# 4   2011-11-27  12.611000           1
# ..         ...        ...         ...
# 823 2014-02-23  12.498105           1
# 824 2014-02-24  11.507970           0
# 825 2014-02-25  11.384361           0
# 826 2014-02-26  11.314600           0
# 827 2014-02-27  11.590049           0
#
# [828 rows x 3 columns]

# %% [markdown]
# **Defining The Model**

# %%
prophet_model = Prophet(yearly_seasonality=True)
prophet_model.add_regressor('is_weekend')

# %% [markdown]
# **Fitting Model**

# %%
prophet_model.fit(prophet_df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/h46kb550.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/20s57f_4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41795', 'data', 'file=/tmp/tmpsn01d8md/h46kb550.json', 'init=/tmp/tmpsn01d8md/20s57f_4.json', 'output', 'file=/tmp/tmpsn01d8md/prophet_model3xqqs1ia/prophet_model-20241204010608.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:06:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:06:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# As a small note, the fitting took only about a few seconds, which makes sense since PROPHET is considered a "fast" model.

# %% [markdown]
# **Forecasting 1 Year Into The Future**

# %%
future_df = prophet_model.make_future_dataframe(periods=365)
future_df['is_weekend'] = pd.concat([prophet_df['is_weekend'], prophet_df['is_weekend'].iloc[-365:].reset_index(drop=True)], ignore_index=True)
forecast = prophet_model.predict(future_df)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1188 2015-02-23  9.832496    8.798421   10.935600
# 1189 2015-02-24  9.681890    8.589345   10.740042
# 1190 2015-02-25  9.579834    8.524023   10.639815
# 1191 2015-02-26  9.433292    8.414858   10.474006
# 1192 2015-02-27  9.411713    8.328485   10.429540

# %% [markdown]
# **Plotting The Forecast**

# %%
prophet_model.plot(forecast)
plt.title("Prophet Predictions")
plt.xlabel("Date")
plt.ylabel("Energy Sum")
plt.show()

# %% [markdown]
# As you can see in the plot, the PROPHET model in its forecasting is practically mimicking the aforementioned loops while decreasing the overall peak of these cycles, which has been shown in the original dataset. Whether or not that assumption is correct is up to debate, but given the limited data we have, this seems like a pretty good forecast overall.
#
# Now, let's repeat the process but with a train test split.

# %% [markdown]
# **Train Test Split**

# %%
train_size = int(len(prophet_df) * 0.7)
train_df = prophet_df.iloc[:train_size]
test_df = prophet_df.iloc[train_size:]

# %% [markdown]
# **Defining The Model Again**

# %%
prophet_model = Prophet(yearly_seasonality=True)
prophet_model.add_regressor('is_weekend')

# %% [markdown]
# **Fitting Model With Train Set**

# %%
prophet_model.fit(train_df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/5dspvbop.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/w1ctk992.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99775', 'data', 'file=/tmp/tmpsn01d8md/5dspvbop.json', 'init=/tmp/tmpsn01d8md/w1ctk992.json', 'output', 'file=/tmp/tmpsn01d8md/prophet_modelwxzn_lk6/prophet_model-20241204010609.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:06:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:06:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# **Forecasting The Test Set**

# %%
future_df = prophet_model.make_future_dataframe(periods=len(test_df), freq='D')
future_df['is_weekend'] = pd.concat([train_df['is_weekend'], test_df['is_weekend'].reset_index(drop=True)], ignore_index=True)
forecast = prophet_model.predict(future_df)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 823 2014-02-23  13.765137   12.663563   14.831541
# 824 2014-02-24  13.201644   12.087904   14.368583
# 825 2014-02-25  13.026682   11.899151   14.061453
# 826 2014-02-26  12.907371   11.802630   14.103471
# 827 2014-02-27  12.765010   11.707267   13.920161

# %% [markdown]
# **Plotting The Forecast**

# %%
prophet_model.plot(forecast)
test_dates = test_df['ds']
test_values = test_df['y']
plt.plot(test_dates, test_values, 'r.', label='Test Y Values')
plt.title("Prophet Predictions")
plt.xlabel("Date")
plt.ylabel("Energy Sum")
plt.show()

# %% [markdown]
# We can see here that the prophet model is sort of "overshooting" the test values, which could be due to a lack of data that provided context in the previous iteration of the model that took the entire dataset.

# %% [markdown]
# **Performance Metrics for Prophet**
#
# To calculate the performance of the Prophet model, we use their built in `cross_validation` and `performance_metrics` functions.

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(prophet_model, initial='500 days', period='180 days', horizon = '20 days')
# Out:
# INFO:prophet:Making 1 forecasts with cutoffs between 2013-06-03 00:00:00 and 2013-06-03 00:00:00
#   0%|          | 0/1 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/626fot7k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpsn01d8md/2xios_29.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85551', 'data', 'file=/tmp/tmpsn01d8md/626fot7k.json', 'init=/tmp/tmpsn01d8md/2xios_29.json', 'output', 'file=/tmp/tmpsn01d8md/prophet_modelkyr_bwzu/prophet_model-20241204010610.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:06:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:06:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0  2 days  0.301853  0.549411  0.549300  0.064696  0.064696  0.062668
# 1  3 days  0.362206  0.601835  0.600496  0.071579  0.071579  0.069092
# 2  4 days  0.394501  0.628093  0.627966  0.074935  0.074935  0.072227
# 3  5 days  0.425300  0.652150  0.651164  0.076761  0.076761  0.073917
# 4  6 days  0.285266  0.534103  0.500465  0.056954  0.056954  0.055120
#
#    coverage
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mse')
plt.title('Mean Squared Error for Prophet Model')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.10/dist-packages/prophet/plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %% [markdown]
# All of the MSE values are below 0.5 which shows that the model is performing pretty well, despite it overshooting.

# %% [markdown]
# #### **LSTM**

# %% [markdown]
# **Imports**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Preparing Data**
#
# As mentioned above, LSTM models are generally more complex than PROPHET models, which requires us to take more effort in selecting our features and hyperparameters.
#
# To start, of course, the prediction variable `y` will be `energy_sum`.
#
# So yeah, let's go ahead and get that data first.

# %%
sample_df = daily_df[daily_df["Acorn_category"] == "Established"]
sample_df = sample_df.drop(columns="LCLid")
sample_df = sample_df.groupby("date")["energy_sum"].mean().reset_index()
sample_df
# Out:
#           date  energy_sum
# 0   2011-11-23   11.551500
# 1   2011-11-24   10.654900
# 2   2011-11-25   11.062214
# 3   2011-11-26   12.207176
# 4   2011-11-27   12.611000
# ..         ...         ...
# 823 2014-02-23   12.498105
# 824 2014-02-24   11.507970
# 825 2014-02-25   11.384361
# 826 2014-02-26   11.314600
# 827 2014-02-27   11.590049
#
# [828 rows x 2 columns]

# %% [markdown]
# In terms of our features, since we know that there is yearly seasonality in our data, we can do a sine and cosine transform on the day of year.
#
# Our motive for doing this is that it would make data points and the start and end of the year be considered closer together, which would not be the case if we simply did day of year (start would be 1 and end would be 365).

# %%
sample_df['day_of_year'] = sample_df['date'].dt.dayofyear
sample_df['sin_day'] = np.sin(2 * np.pi * sample_df['day_of_year'] / 365)
sample_df['cos_day'] = np.cos(2 * np.pi * sample_df['day_of_year'] / 365)
sample_df = sample_df.drop(columns="day_of_year")
sample_df
# Out:
#           date  energy_sum   sin_day   cos_day
# 0   2011-11-23   11.551500 -0.608477  0.793572
# 1   2011-11-24   10.654900 -0.594727  0.803928
# 2   2011-11-25   11.062214 -0.580800  0.814046
# 3   2011-11-26   12.207176 -0.566702  0.823923
# 4   2011-11-27   12.611000 -0.552435  0.833556
# ..         ...         ...       ...       ...
# 823 2014-02-23   12.498105  0.801361  0.598181
# 824 2014-02-24   11.507970  0.811539  0.584298
# 825 2014-02-25   11.384361  0.821477  0.570242
# 826 2014-02-26   11.314600  0.831171  0.556017
# 827 2014-02-27   11.590049  0.840618  0.541628
#
# [828 rows x 4 columns]

# %% [markdown]
# We also chose to add a sine and cosine transform on day of week as well as keep a boolean `is_weekend` feature.

# %%
sample_df['day_of_week'] = sample_df['date'].dt.dayofweek
sample_df["is_weekend"] = sample_df["date"].apply(lambda x: int(x.dayofweek > 4))
sample_df['sin_day_of_week'] = np.sin(2 * np.pi * sample_df['day_of_week'] / 7)
sample_df['cos_day_of_week'] = np.cos(2 * np.pi * sample_df['day_of_week'] / 7)
sample_df = sample_df.drop(columns="day_of_week")
sample_df
# Out:
#           date  energy_sum   sin_day   cos_day  is_weekend  sin_day_of_week  \
# 0   2011-11-23   11.551500 -0.608477  0.793572           0         0.974928
# 1   2011-11-24   10.654900 -0.594727  0.803928           0         0.433884
# 2   2011-11-25   11.062214 -0.580800  0.814046           0        -0.433884
# 3   2011-11-26   12.207176 -0.566702  0.823923           1        -0.974928
# 4   2011-11-27   12.611000 -0.552435  0.833556           1        -0.781831
# ..         ...         ...       ...       ...         ...              ...
# 823 2014-02-23   12.498105  0.801361  0.598181           1        -0.781831
# 824 2014-02-24   11.507970  0.811539  0.584298           0         0.000000
# 825 2014-02-25   11.384361  0.821477  0.570242           0         0.781831
# 826 2014-02-26   11.314600  0.831171  0.556017           0         0.974928
# 827 2014-02-27   11.590049  0.840618  0.541628           0         0.433884
#
#      cos_day_of_week
# 0          -0.222521
# ...

# %% [markdown]
# The reason for this is because we noticed that there are also fluctuations in energy over the week with clear peaks during the weekend, as seen in the below plot

# %%
import matplotlib.dates as mdates

sample_df = pd.merge(left = sample_df, right = weather_df[["date", "temperatureAverage"]], left_on = "date", right_on = "date")
sample_df
min_temp, max_temp = sample_df["temperatureAverage"].min(), sample_df["temperatureAverage"].max()
sample_df['day_of_week'] = sample_df['date'].dt.dayofweek
saturdays = sample_df[sample_df["day_of_week"] == 6]["date"].reset_index().drop(columns=["index"])
sample_df = sample_df.drop(columns="day_of_week")
saturdays = saturdays[saturdays["date"] < "2012-02-20"]
fig, ax = plt.subplots()
sample_df[:90].plot("date", "energy_sum", ax=ax)
ax.xaxis_date()
saturdays_numeric = mdates.date2num(saturdays)
for saturday in saturdays_numeric:
    ax.axvline(x=saturday[0], color='g', linestyle='dotted')
plt.title("Energy Sum Over Time With Weekend Marks")
plt.xlabel("Date")
plt.ylabel("Energy Sum")
plt.show()

# %% [markdown]
# Also, since our data is slightly decreasing per season, we also added a linear `time_since_start` feature.

# %%
sample_df['time_since_start'] = (sample_df['date'] - sample_df['date'].min()).dt.days
sample_df
# Out:
#           date  energy_sum   sin_day   cos_day  is_weekend  sin_day_of_week  \
# 0   2011-11-23   11.551500 -0.608477  0.793572           0         0.974928
# 1   2011-11-24   10.654900 -0.594727  0.803928           0         0.433884
# 2   2011-11-25   11.062214 -0.580800  0.814046           0        -0.433884
# 3   2011-11-26   12.207176 -0.566702  0.823923           1        -0.974928
# 4   2011-11-27   12.611000 -0.552435  0.833556           1        -0.781831
# ..         ...         ...       ...       ...         ...              ...
# 823 2014-02-23   12.498105  0.801361  0.598181           1        -0.781831
# 824 2014-02-24   11.507970  0.811539  0.584298           0         0.000000
# 825 2014-02-25   11.384361  0.821477  0.570242           0         0.781831
# 826 2014-02-26   11.314600  0.831171  0.556017           0         0.974928
# 827 2014-02-27   11.590049  0.840618  0.541628           0         0.433884
#
# ...

# %% [markdown]
# Also, since albeit temperature is mostly seasonal, there will naturally be noise within the temperature over time. And since it is clear that temperature does affect energy usage, we chose to also add a `temperatureAverage` feature.

# %%
sample_df = pd.merge(left = sample_df, right = weather_df[["date", "temperatureAverage"]], left_on = "date", right_on = "date")
sample_df
# Out:
#           date  energy_sum   sin_day   cos_day  is_weekend  sin_day_of_week  \
# 0   2011-11-23   11.551500 -0.608477  0.793572           0         0.974928
# 1   2011-11-24   10.654900 -0.594727  0.803928           0         0.433884
# 2   2011-11-25   11.062214 -0.580800  0.814046           0        -0.433884
# 3   2011-11-26   12.207176 -0.566702  0.823923           1        -0.974928
# 4   2011-11-27   12.611000 -0.552435  0.833556           1        -0.781831
# ..         ...         ...       ...       ...         ...              ...
# 823 2014-02-23   12.498105  0.801361  0.598181           1        -0.781831
# 824 2014-02-24   11.507970  0.811539  0.584298           0         0.000000
# 825 2014-02-25   11.384361  0.821477  0.570242           0         0.781831
# 826 2014-02-26   11.314600  0.831171  0.556017           0         0.974928
# 827 2014-02-27   11.590049  0.840618  0.541628           0         0.433884
#
# ...

# %% [markdown]
# Now let's see if there is any missing data.

# %%
sample_df.isna().sum()
# Out:
# date                    0
# energy_sum              0
# sin_day                 0
# cos_day                 0
# is_weekend              0
# sin_day_of_week         0
# cos_day_of_week         0
# temperatureAverage_x    0
# time_since_start        0
# temperatureAverage_y    0
# dtype: int64

# %% [markdown]
# There seems to be no missing data, which is great.

# %% [markdown]
# **Train Test Split**
#
# We chose a 70-30 train test split for this tutorial.

# %%
dataset = sample_df.drop(columns=["date"])

train_size = int(len(dataset) * 0.7)
dataset_train, dataset_test = dataset[:train_size], dataset[train_size:]

# %% [markdown]
# **Scaling Dataset**
#
# Since we are using LSTM, we should also scale our data. In our case, we chose to use MinMaxScaling.

# %%
scaler = MinMaxScaler()
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %% [markdown]
# **Defining X and Y**
#
# For our X, we want a lagged list of our target variable as well as features.
# To do this, we windowed the dataset with the create_windows function

# %%
def create_windows(dataset, look_back, forecast_steps):
    X, y = [], []
    for i in range(len(dataset) - look_back - forecast_steps):
        X.append(dataset[i:i+look_back])
        y.append(dataset[i+look_back:i+look_back+forecast_steps, 0])
    return np.array(X), np.array(y)

look_back, forecast_steps = 30, 30
X_train, y_train = create_windows(dataset_train, look_back, forecast_steps)
X_test, y_test = create_windows(dataset_test, look_back, forecast_steps)

# %% [markdown]
# **Defining Our Model**
#
# To start, let's try a single LSTM layer with a dropout and dense layer as well

# %%
model = Sequential([
    LSTM(32, input_shape=(X_train.shape[1:]), kernel_regularizer=l2(0.0001)),
    Dense(30)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# **Fitting Model**

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
history = model.fit(X_train, y_train, epochs=125, batch_size=32)
# Out:
# Epoch 1/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1781 - mae: 0.3355
# Epoch 2/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0762 - mae: 0.2136
# Epoch 3/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0406 - mae: 0.1535
# Epoch 4/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0206 - mae: 0.1083
# Epoch 5/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0163 - mae: 0.0963
# Epoch 6/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0145 - mae: 0.0888
# Epoch 7/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0124 - mae: 0.0810
# Epoch 8/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0125 - mae: 0.0806
# Epoch 9/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0122 - mae: 0.0803
# Epoch 10/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0112 - mae: 0.0755
# Epoch 11/125
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0111 - mae: 0.0751
# Epoch 12/125
# ...

# %% [markdown]
# **Plotting Loss & MAE**
#
# Below, we can see that loss decreases significantly initially then starts to stagnate.

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['mae'], label='MAE')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss & MAE')
plt.show()

# %% [markdown]
# **Evaluating The Model**

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mae: 0.0596
# [0.008054430596530437, 0.07038445770740509]

# %%
model.evaluate(X_train, y_train)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - mae: 0.0592
# [0.005730821285396814, 0.05511147528886795]

# %%
train_predict = model.predict(X_train)
train_predict = np.array([scaler.inverse_transform(
    np.hstack([predict.reshape(-1, 1), np.zeros((predict.shape[0], X_train.shape[-1] - 1))])
)[:, 0] for predict in train_predict]).tolist()
test_predict = model.predict(X_test)
test_predict = np.array([scaler.inverse_transform(
    np.hstack([predict.reshape(-1, 1), np.zeros((predict.shape[0], X_train.shape[-1] - 1))])
)[:, 0] for predict in test_predict]).tolist()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
plt.plot(np.arange(len(dataset["energy_sum"])), dataset["energy_sum"], label="Original Data")
for i in range(len(train_predict)):
  plt.plot(np.arange(i+look_back, i+look_back+forecast_steps), train_predict[i])
for i in range(len(train_predict), len(train_predict) + len(test_predict)):
  plt.plot(np.arange(i+2*look_back+forecast_steps, i+2*look_back+2*forecast_steps), test_predict[i-len(train_predict)])
plt.title("Predictions Over Time")
plt.xlabel("Time Index")
plt.ylabel("Energy Sum")
plt.show()

# %%
plt.plot(np.arange(len(dataset["energy_sum"])), dataset["energy_sum"], label="Original Data")
for i in range(0, len(train_predict), 30):
  plt.plot(np.arange(i+look_back, i+look_back+forecast_steps), train_predict[i])
for i in range(len(train_predict), len(train_predict) + len(test_predict), 30):
  plt.plot(np.arange(i+2*look_back+forecast_steps, i+2*look_back+2*forecast_steps), test_predict[i-len(train_predict)])
plt.title("Predictions Over Time Every 30 Time Indices")
plt.xlabel("Time Index")
plt.ylabel("Energy Sum")
plt.show()
plt.show()

# %% [markdown]
# We can see here that the model is performing relatively okay, though we could probably have done more tuning and feature engineering to make it better.
#
# Overall, if we had more data to work with, the LSTM model probably could have performed better.

# %% [markdown]
# <a name="conc"></a>
#
# ### **Insights and Conclusions**

# %% [markdown]
# Through several visualizations and hypothesis tests, our initial data exploration and analysis revealed that energy consumption of specific households depends heavily on generalized household demographics, weather characteristics, and temporal factors; the data shows clear weekly and seasonal trends. Our time-series models support and extend these trends, and also continue a pattern of decreasing peaks in energy usage that is present in the data we have.
# These trends and predictions can be used by energy companies to manage energy grid operations more efficiently to prevent energy waste, and maintain energy availability to prevent outages, with knowledge of likely future energy demands.
#
# The dataset we chose has less than three years of data, which only contains one cycle of seasons. For future analysis, with more years of data, we could further refine the training and precision of our time series models with techniques like K-fold cross validation. Also, there is a wealth of more specific data on these households including specific appliances each household has, number and ages of household members, and level of insulation, among other information. However, due to restrictions from the UK Energy Service, we were not able to use this data – the reason is that the service scrambled the IDs of all households, so it is not possible to match up households in our energy dataset with households in our household context dataset. Currently, our models are predicting average consumption for a whole Acorn group; this information can be used to make more informed and precise predictions about the energy consumption of individual households, which can help these individual households further understand and plan for their future energy usage.
